# %% [markdown]
# # Scraping Tarot Cards from Flickr
#
# I found two really great accounts on Flickr that have some variations of classic tarot decks as well as some pretty unique ones:
# * ['CBD Tarot de Marseille' courtesy of Yoav Ben-Dov](https://www.flickr.com/photos/48485995@N00/)
# * [Multiple decks courtesy of "Sumada's Treasure Box"](https://www.flickr.com/photos/sumadas-treasure-box/albums/with/72157650242007982)
#
# Between these accounts, I should be able to add about 300-400 cards to my dataset, which should hopefully be sufficient to train with StyleGAN2-ADA.
#
# Flickr has an API that I can use to pull the photos and thanks to [Alexis Mignon](https://github.com/alexis-mignon/python-flickr-api), I'm armed with a few methods that'll make this scrape a breeze.

# %% [markdown]
# ## Setup

# %%
import flickr_api
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import flickr_api
#       2 import os
#
# ModuleNotFoundError: No module named 'flickr_api'

# %%
base_path = os.getcwd()
base_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 base_path = os.getcwd()
#       2 base_path
#
# NameError: name 'os' is not defined

# %%
new_folder = '/data_files/other_decks'

# %%
path = base_path + new_folder

# %%
path
# Out:
# '/Users/scrapfish/coding/metis/project5/data_files/other_decks'

# %%
os.mkdir(path)

# %%
fkey = 'b936fcec361b44ec6afd82c3287167e6'
fsecret = '794a111740f036cf'

flickr_api.set_keys(api_key=fkey, 
                    api_secret=fsecret)

# %% [markdown]
# ## Flickr Scrape

# %%
def download_cards(photoset, file_prefix):
    i = 0
    print('Downloading photos...')
    for photo in photoset:
        
        if i < 10:
            photo.save(f'{path}/{file_prefix}0{str(i)}')
        else:
            photo.save(f'{path}/{file_prefix}{str(i)}')
        
        i += 1
    
    print("Download complete!")

# %% [markdown]
# ### CBD Tarot de Marseille from 'yoav bd'
#
# These tarot card images are the only photos for this user, so I can just pull them all from the account's main 'photostream'.

# %%
cbd = flickr_api.Person.findByUserName('yoav bd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cbd = flickr_api.Person.findByUserName('yoav bd')
#
# NameError: name 'flickr_api' is not defined

# %%
cbd_deck = cbd.getPhotos()

# %%
cbd_deck
# Out:
# [Photo(id=b'5771299887', title=b'a19'), Photo(id=b'5771299473', title=b'a20'), Photo(id=b'5771842194', title=b'a21'), Photo(id=b'5771298787', title=b'a22'), Photo(id=b'5771298539', title=b'b01'), Photo(id=b'5771840542', title=b'a14'), Photo(id=b'5771840228', title=b'a15'), Photo(id=b'5771839942', title=b'a16'), Photo(id=b'5771839668', title=b'a17'), Photo(id=b'5771296043', title=b'a07'), Photo(id=b'5771295483', title=b'a09'), Photo(id=b'5771295299', title=b'a10'), Photo(id=b'5771838252', title=b'a11'), Photo(id=b'5771838072', title=b'a06'), Photo(id=b'5771837864', title=b'a03'), Photo(id=b'5771837664', title=b'a04'), Photo(id=b'5771837316', title=b'a01'), Photo(id=b'5771294123', title=b'a02'), Photo(id=b'5791074238', title=b'cardback'), Photo(id=b'5771313515', title=b'z01'), Photo(id=b'5771313383', title=b'e13'), Photo(id=b'5771313223', title=b'e14'), Photo(id=b'5771855796', title=b'e09'), Photo(id=b'5771312859', title=b'e10'), Photo(id=b'5771312673', title=b'e11'), Photo(id=b'5771855282', title=b'e12'), Photo(id=b'5771855118', title=b'e08'), Photo(id=b'5771854944', title=b'e03'), Photo(id=b'5771854816', title=b'e04'), Photo(id=b'5771854654', title=b'e05'), Photo(id=b'5771311731', title=b'e06'), Photo(id=b'5771311571', title=b'e07'), Photo(id=b'5771854192', title=b'e02'), Photo(id=b'5771854046', title=b'd11'), Photo(id=b'5771853776', title=b'd12'), Photo(id=b'5771310735', title=b'd13'), Photo(id=b'5771310469', title=b'd14'), Photo(id=b'5771852846', title=b'e01'), Photo(id=b'5771309925', title=b'd08'), Photo(id=b'5771309615', title=b'd09'), Photo(id=b'5771309309', title=b'd10'), Photo(id=b'5771851862', title=b'd05'), Photo(id=b'5771308705', title=b'd06'), Photo(id=b'5771851204', title=b'd07'), Photo(id=b'5771850950', title=b'd04'), Photo(id=b'5771307821', title=b'c13'), Photo(id=b'5771307557', title=b'c14'), Photo(id=b'5771307259', title=b'd01'), Photo(id=b'5771849782', title=b'd02'), Photo(id=b'5771849458', title=b'd03'), Photo(id=b'5771306339', title=b'c12'), Photo(id=b'5771848888', title=b'c07'), Photo(id=b'5771305815', title=b'c08'), Photo(id=b'5771305553', title=b'c09'), Photo(id=b'5771848022', title=b'c10'), Photo(id=b'5771305071', title=b'c11'), Photo(id=b'5771847610', title=b'c06'), Photo(id=b'5771847324', title=b'c01'), Photo(id=b'5771847042', title=b'c02'), Photo(id=b'5771303845', title=b'c03'), Photo(id=b'5771303521', title=b'c04'), Photo(id=b'5771303203', title=b'c05'), Photo(id=b'5771845946', title=b'b14'), Photo(id=b'5771845760', title=b'b09'), Photo(id=b'5771845602', title=b'b10'), Photo(id=b'5771845348', title=b'b11'), Photo(id=b'5771845088', title=b'b12'), Photo(id=b'5771301841', title=b'b13'), Photo(id=b'5771844532', title=b'b08'), Photo(id=b'5771844250', title=b'b03'), Photo(id=b'5771300997', title=b'b04'), Photo(id=b'5771300743', title=b'b05'), Photo(id=b'5771843464', title=b'b06'), Photo(id=b'5771843130', title=b'b07'), Photo(id=b'5771298325', title=b'b02'), Photo(id=b'5771841074', title=b'a18'), Photo(id=b'5771840818', title=b'a13'), Photo(id=b'5771296297', title=b'a12'), Photo(id=b'5771295725', title=b'a08'), Photo(id=b'5771294511', title=b'a05')];Info(page=1, perpage=100, pages=1, total=80)

# %% [markdown]
# Should get 80 photos from this pull

# %%
download_cards(cbd_deck, 'cbd_')
# Out:
# Downloading photos...
# Download complete!

# %% [markdown]
# Let's take a look!

# %%
from IPython.display import Image, display
import imageio.v2 as imageio

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(5,8))
img1 = imageio.imread('..\data_files\other_decks\cbd_00.jpg')
plt.imshow(img1)
plt.show()

# %%
img1.shape
# Out:
# (567, 293, 3)

# %% [markdown]
# ### Multiple decks from user  "Sumada's Treasure Box"
#
# This user has a ton of great images. I don't want everything, but just a few select albums of tarot cards. With the Flickr API, I can scrape these by album name.

# %%
stb = flickr_api.Person.findByUserName("Sumada's Treasure Box")

# %%
photosets = stb.getPhotosets()

# %%
len(photosets)
# Out:
# 117

# %%
photosets
# Out:
# [Photoset(id=b'72157678553481386', title=b'Niki de Saint Phal...), Photoset(id=b'72157664716208662', title=b'Ancien Tarot de Ma...), Photoset(id=b'72157661719547274', title=b'Lequart Tarot de B...), Photoset(id=b'72157656493668328', title=b'Resplendent in Div...), Photoset(id=b'72157651749969945', title=b'The New Tarot Deck...), Photoset(id=b'72157650880299381', title=b"Tarot d'Epinal"), Photoset(id=b'72157650242007982', title=b'Tarot Classic late...), Photoset(id=b'72157650166626035', title=b'Swiss 1JJ Wehman 1...), Photoset(id=b'72157650096412246', title=b'Swiss 1JJ Muller &...), Photoset(id=b'72157649750380350', title=b'Swiss 1JJ USGS 196...), Photoset(id=b'72157650111940882', title=b'Thoth 4 Language E...), Photoset(id=b'72157645449117289', title=b'Tarot Collectors F...), Photoset(id=b'72157642938396814', title=b'Grand Tarot Bellin...), Photoset(id=b'72157642586229013', title=b'1JJ Phanomene - Or...), Photoset(id=b'72157642585365793', title=b'Swiss 1JJ - US Gam...), Photoset(id=b'72157642582094215', title=b'Tarocs No.1JJ - We...), Photoset(id=b'72157642410730585', title=b'Etteilla, Wattilau...), Photoset(id=b'72157642364911135', title=b'Leboroni Tarot'), Photoset(id=b'72157642355706105', title=b'Tarocchi di Marsig...), Photoset(id=b'72157641090217194', title=b'Your Destiny by th...), Photoset(id=b'72157641084695624', title=b'Tarot Classic 1970...), Photoset(id=b'72157641074385785', title=b'Francois Gassmann'), Photoset(id=b'72157640864458973', title=b'Nas. Conver Compos...), Photoset(id=b'72157640624099224', title=b'Here come the Cava...), Photoset(id=b'72157637982123985', title=b'I Naibi di Giovann...), Photoset(id=b'72157637982504384', title=b'I Naibi di Giovann...), Photoset(id=b'72157637742351633', title=b'Hoi Polloi Tarot -...), Photoset(id=b'72157637150343163', title=b'Deutsches Original...), Photoset(id=b'72157636227300783', title=b'Le Tarot de Marsei...), Photoset(id=b'72157636227136404', title=b'Spanish Tarot - H....), Photoset(id=b'72157635560258116', title=b'Ignaz Krebs TdM 18...), Photoset(id=b'72157635558920991', title=b'The Keishobou Taro...), Photoset(id=b'72157635558480291', title=b'Tarot des Centurie...), Photoset(id=b'72157634144383225', title=b"Grand Jeu de L'Ora...), Photoset(id=b'72157634149140002', title=b"Grand Jeu de L'Ora...), Photoset(id=b'72157632949844553', title=b'N. Conver Bicenten...), Photoset(id=b'72157632900596118', title=b"Pixie's Astounding...), Photoset(id=b'72157632795961358', title=b'Jacques Vieville -...), Photoset(id=b'72157632789764297', title=b'Jacques Vieville -...), Photoset(id=b'72157632418671239', title=b'The First Pentacle...), Photoset(id=b'72157632418558339', title=b'Ballet West Tarot'), Photoset(id=b'72157632422668082', title=b'5 cards by The Foo...), Photoset(id=b'72157632266576696', title=b'J.A. Knapp Tarot 1...), Photoset(id=b'72157631859934341', title=b'Tarots Egipcios - ...), Photoset(id=b'72157631774542489', title=b'Tinker, Tailor, So...), Photoset(id=b'72157631774663132', title=b'Oliver Twist Snap'), Photoset(id=b'72157631774339193', title=b'Snap'), Photoset(id=b'72157631728544194', title=b'The Brotherhood of...), Photoset(id=b'72157631727434309', title=b'Practical Astrolog...), Photoset(id=b'72157631727221578', title=b'Egyptian Tarot Dec...), Photoset(id=b'72157631727151351', title=b'Tarots Egipcios - ...), Photoset(id=b'72157631727086315', title=b'Egipcios Kier Taro...), Photoset(id=b'72157631726971851', title=b'Tarots Egipcios - ...), Photoset(id=b'72157631725690116', title=b'Cagliostro Tarot 1...), Photoset(id=b'72157631674395833', title=b"Magician's Tables"), Photoset(id=b'72157631665525433', title=b'Luxus Tarock - Pia...), Photoset(id=b'72157631656688015', title=b'TdM - Nicolas Conv...), Photoset(id=b'72157631656419340', title=b'Le TdM - Paul Mart...), Photoset(id=b'72157631656373419', title=b'Le TdM - Paul Mart...), Photoset(id=b'72157631656194853', title=b'Ancien TdM - BP Gr...), Photoset(id=b'72157631655998952', title=b'T of M - BP Grimau...), Photoset(id=b ...

# %% [markdown]
# Below is a list of albums I want by name, and the prefix I'll use when downloading them.

# %%
# Example title from the photoset list above
photosets[0].title
# Out:
# 'Niki de Saint Phalle Tarot Cards'

# %%
albums_dict = {'Ancien Tarot de Marseille': 'atm_',
               'Lequart Tarot de Besancon': 'ltb_',
               "Tarot d'Epinal": 'te_',
               'Tarot Classic late 19th.Century': 'classic_',
               'Tarocchi di Marsiglia - Mario Delucis': 'tm_',
               'Your Destiny by the Tarots': 'destiny_',
               'Nas. Conver Composite 1870-1960 Deck': 'comp_',
               'Hoi Polloi Tarot - Reiss Games Inc. 1972': 'reiss_',
               'The Keishobou Tarot': 'keishobou_',
               "Grand Jeu de L'Oracle des Dames": 'od_',
               "Oswald Wirth's Signature Deck - c.1926": 'ow_',
               'The New Tarot Deck': 'new_'
              }

# %%
for ps in photosets:
    idx = 0
    if ps.title in albums_dict.keys():
        print(f'Fetching photos for {ps.title}')
        photos = ps.getPhotos()
        prefix = albums_dict[ps.title]
        download_cards(photos, prefix)
# Out:
# Fetching photos for Ancien Tarot de Marseille
# Downloading photos...
# Download complete!
# Fetching photos for Lequart Tarot de Besancon
# Downloading photos...
# Download complete!
# Fetching photos for The New Tarot Deck
# Downloading photos...
# Download complete!
# Fetching photos for Tarot d'Epinal
# Downloading photos...
# Download complete!
# Fetching photos for Tarot Classic late 19th.Century
# Downloading photos...
# Download complete!
# Fetching photos for Tarocchi di Marsiglia - Mario Delucis
# Downloading photos...
# Download complete!
# Fetching photos for Your Destiny by the Tarots
# Downloading photos...
# Download complete!
# Fetching photos for Nas. Conver Composite 1870-1960 Deck
# Downloading photos...
# Download complete!
# Fetching photos for Hoi Polloi Tarot - Reiss Games Inc. 1972
# Downloading photos...
# Download complete!
# Fetching photos for The Keishobou Tarot
# Downloading photos...
# Download complete!
# Fetching photos for Grand Jeu de L'Oracle des Dames
# Downloading photos...
# Download complete!
# Fetching photos for Oswald Wirth's Signature Deck - c.1926
# Downloading photos...
# Download complete!

# %%
import os
onlyfiles = next(os.walk(path+"/"))[2] #dir is your directory path as string
print("Number of photos scraped: ",len(onlyfiles))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 import os
# ----> 2 onlyfiles = next(os.walk(path+"/"))[2] #dir is your directory path as string
#       3 print("Number of photos scraped: ",len(onlyfiles))
#
# NameError: name 'path' is not defined

# %% [markdown]
# This plus the 79 photos from the Rider-Waite deck gives me just over 500 photos!
#
# I will have to review what's been downloaded and remove a few -- not all of the cards are face up, some are just the backs of the cards or other images in that album. But not a bad start!
#
# Let's get a random sampling of cards:

# %%
plt.figure(figsize=(10, 8))

for i, prefix in enumerate(albums_dict.values()):
    img = imageio.imread(f'data_files/other_decks/{prefix}05.jpg')
    plt.subplot(3,4,i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 plt.figure(figsize=(10, 8))
# ----> 3 for i, prefix in enumerate(albums_dict.values()):
#       4     img = imageio.imread(f'data_files/other_decks/{prefix}05.jpg')
#       5     plt.subplot(3,4,i+1)
#
# NameError: name 'albums_dict' is not defined

# %% [markdown]
# Great! Now to manually cull the decks a bit!
